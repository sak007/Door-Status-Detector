# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras import layers
import time
import pandas as pd


def readBackFiles(folder):
    x = []
    data=pd.read_csv(folder + "gx.csv", header=None)
    check = data.isna().sum()
    if sum(check) > 0:
        raise Exception("NANs in data")
    x.append(data.values)
    x = np.dstack(x)
    y = pd.read_csv(folder + "class.csv", header=None)
    return x, y

classes = {0:"Close", 1:"Open"}

TrainFolder = "../../data/train/"
ValFolder = "../../data/val/"
TestFolder = "../../data/test/"

trainX,trainY = readBackFiles(TrainFolder)
trainYOneHot = tf.keras.utils.to_categorical(trainY)
print("Train")
print(trainX.shape)
print(trainY.shape)
valX,valY = readBackFiles(ValFolder)
valYOneHot = tf.keras.utils.to_categorical(valY)
print("Val")
print(valX.shape)
print(valY.shape)
print("Test")
testX,testY = readBackFiles(TestFolder)
print(testX.shape)
print(testY.shape)
testYOneHot = tf.keras.utils.to_categorical(testY)
# Out:
# Train
# (23400, 596, 1)
# (23400, 1)
# Val
# (56, 596, 1)
# (56, 1)
# Test
# (70, 596, 1)
# (70, 1)

# %%
def fitModel(model, trainX, trainY, valX, valY, epochs, batchSize, verbose,myCallbacks=None):
    model.compile(loss='categorical_crossentropy', optimizer=tf.optimizers.Adam(learning_rate=.0001),
                  metrics=['acc', "Precision", "Recall"])
    if myCallbacks == None:
        history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchSize, verbose=verbose,
                            validation_data=(valX, valY))

    else:
        history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchSize, verbose=verbose,
                            validation_data=(valX, valY), callbacks=myCallbacks)
    return model, history

def createModel2(xShape, yShape):
    verbose = 1
    _, timesteps, channels = xShape
    _, numCategories = yShape
    model = tf.keras.Sequential([
        layers.Conv1D(filters=64, kernel_size=8, strides=2, activation="relu", input_shape=(timesteps, channels)),
        layers.Dropout(.2),
        layers.MaxPool1D(pool_size=2),
        layers.BatchNormalization(),
        layers.Conv1D(filters=48, kernel_size=4, strides=1, activation="relu", input_shape=(timesteps, channels)),
        layers.Dropout(.2),
        layers.MaxPool1D(pool_size=2),
        layers.BatchNormalization(),
        layers.Flatten(),
        layers.Dense(768, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(.5),
        layers.Dense(384, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(.5),
        #layers.Dense(30, activation="relu"),
        layers.Dense(numCategories, activation="softmax")
    ])
    return model

def createModel(xShape, yShape):
    verbose = 1
    _, timesteps, channels = xShape
    _, numCategories = yShape
    model = tf.keras.Sequential([
        layers.Conv1D(filters=32, kernel_size=4, strides=2, activation="relu", input_shape=(timesteps, channels)),
        layers.Dropout(.2),
        layers.MaxPool1D(pool_size=2),
        layers.BatchNormalization(),
        layers.Conv1D(filters=24, kernel_size=2, strides=1, activation="relu", input_shape=(timesteps, channels)),
        layers.Dropout(.2),
        layers.MaxPool1D(pool_size=2),
        layers.BatchNormalization(),
        layers.Flatten(),
        layers.Dense(64, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(.5),
        layers.Dense(32, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(.5),
        #layers.Dense(30, activation="relu"),
        layers.Dense(numCategories, activation="softmax")
    ])
    return model

# %%
earlyStoppingPatience = 5 # Early stopping
reduceLRPatience = 4
epochs = 15
batchSize = 32

#BaseModelPath = "model/mymodel.h5"
BaseModelPath = "model/cp-{epoch:04d}"
earlystopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=earlyStoppingPatience,restore_best_weights=False, mode="max", verbose=1)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_acc', factor=0.1,patience=reduceLRPatience, 
                              verbose=1, mode='max')
checkpoint = tf.keras.callbacks.ModelCheckpoint(BaseModelPath,  verbose=1, save_best_only=False,
    save_weights_only=False, save_freq='epoch')
myCallbacks = [checkpoint]
#myCallbacks = [reduce_lr, checkpoint]
#myCallbacks = [earlystopping, reduce_lr, checkpoint]

# %%
# !rm -rf model
# !mkdir model
start = time.time()
myModel = createModel(trainX.shape, trainYOneHot.shape)
myModel, history = fitModel(myModel, trainX, trainYOneHot, valX, valYOneHot, epochs, batchSize, 2, myCallbacks)
end = time.time() - start
print("Model trainined in %d s" % end)

#numEpochsUsed = len(history.history["loss"]) - earlyStoppingPatience
#print("Trained using %d epochs" % numEpochsUsed)
# Out:
# Metal device set to: Apple M1 Max
#
# systemMemory: 64.00 GB
# maxCacheSize: 21.33 GB
#
# Epoch 1/15
# 2022-04-02 20:52:31.093223: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-04-02 20:52:31.093828: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-04-02 20:52:31.264721: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-04-02 20:52:31.722148: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: saving model to model/cp-0001
# 2022-04-02 20:52:45.296268: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-02 20:52:45.812746: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: model/cp-0001/assets
# 732/732 - 15s - loss: 0.1045 - acc: 0.9638 - precision: 0.9638 - recall: 0.9638 - val_loss: 0.1229 - val_acc: 0.9464 - val_precision: 0.9464 - val_recall: 0.9464 - 15s/epoch - 21ms/step
# Epoch 2/15
#
# Epoch 2: saving model to model/cp-0002
# INFO:tensorflow:Assets written to: model/cp-0002/assets
# 732/732 - 13s - loss: 0.0131 - acc: 0.9975 - precision: 0.9975 - recall: 0.9975 - val_loss: 0.0850 - val_acc: 0.9464 - val_precision: 0.9464 - val_recall: 0.9464 - 13s/epoch - 17ms/step
# Epoch 3/15
#
# Epoch 3: saving model to model/cp-0003
# INFO:tensorflow:Assets written to: model/cp-0003/assets
# 732/732 - 12s - loss: 0.0061 - acc: 0.9990 - precision: 0.9990 - recall: 0.9990 - val_loss: 0.0618 - val_acc: 0.9821 - val_precision: 0.9821 - val_recall: 0.9821 - 12s/epoch - 17ms/step
# Epoch 4/15
#
# Epoch 4: saving model to model/cp-0004
# INFO:tensorflow:Assets written to: model/cp-0004/assets
# 732/732 - 12s - loss: 0.0033 - acc: 0.9994 - precision: 0.9994 - recall: 0.9994 - val_loss: 0.0462 - val_acc: 0.9821 - val_precision: 0.9821 - val_recall: 0.9821 - 12s/epoch - 17ms/step
# Epoch 5/15
#
# Epoch 5: saving model to model/cp-0005
# INFO:tensorflow:Assets written to: model/cp-0005/assets
# 732/732 - 13s - loss: 0.0021 - acc: 0.9997 - precision: 0.9997 - recall: 0.9997 - val_loss: 0.0405 - val_acc: 0.9821 - val_precision: 0.9821 - val_recall: 0.9821 - 13s/epoch - 17ms/step
# Epoch 6/15
#
# Epoch 6: saving model to model/cp-0006
# INFO:tensorflow:Assets written to: model/cp-0006/assets
# 732/732 - 12s - loss: 0.0014 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0265 - val_acc: 0.9821 - val_precision: 0.9821 - val_recall: 0.9821 - 12s/epoch - 17ms/step
# Epoch 7/15
#
# Epoch 7: saving model to model/cp-0007
# INFO:tensorflow:Assets written to: model/cp-0007/assets
# 732/732 - 13s - loss: 0.0013 - acc: 0.9997 - precision: 0.9997 - recall: 0.9997 - val_loss: 0.0246 - val_acc: 0.9821 - val_precision: 0.9821 - val_recall: 0.9821 - 13s/epoch - 17ms/step
# Epoch 8/15
#
# Epoch 8: saving model to model/cp-0008
# INFO:tensorflow:Assets written to: model/cp-0008/assets
# 732/732 - 12s - loss: 7.9773e-04 - acc: 0.9999 - precision: 0.9999 - recall: 0.9999 - val_loss: 0.0416 - val_acc: 0.9821 - val_precision: 0.9821 - val_recall: 0.9821 - 12s/epoch - 17ms/step
# Epoch 9/15
#
# Epoch 9: saving model to model/cp-0009
# INFO:tensorflow:Assets written to: model/cp-0009/assets
# 732/732 - 13s - loss: 4.2483e-04 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0254 - val_acc: 0.9821 - val_precision: 0.9821 - val_recall: 0.9821 - 13s/epoch - 18ms/step
# Epoch 10/15
#
# Epoch 10: saving model to model/cp-0010
# INFO:tensorflow:Assets written to: model/cp-0010/assets
# 732/732 - 13s - loss: 5.0323e-04 - acc: 0.9999 - precision: 0.9999 - recall: 0.9999 - val_loss: 0.0105 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 13s/epoch - 17ms/step
# Epoch 11/15
#
# Epoch 11: saving model to model/cp-0011
# INFO:tensorflow:Assets written to: model/cp-0011/assets
# 732/732 - 12s - loss: 4.2159e-04 - acc: 0.9999 - precision: 0.9999 - recall: 0.9999 - val_loss: 0.0167 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 12s/epoch - 17ms/step
# Epoch 12/15
#
# Epoch 12: saving model to model/cp-0012
# INFO:tensorflow:Assets written to: model/cp-0012/assets
# 732/732 - 13s - loss: 3.1827e-04 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0069 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 13s/epoch - 18ms/step
# Epoch 13/15
#
# Epoch 13: saving model to model/cp-0013
# INFO:tensorflow:Assets written to: model/cp-0013/assets
# 732/732 - 13s - loss: 2.7038e-04 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0124 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 13s/epoch - 18ms/step
# Epoch 14/15
#
# Epoch 14: saving model to model/cp-0014
# INFO:tensorflow:Assets written to: model/cp-0014/assets
# 732/732 - 12s - loss: 1.6255e-04 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0152 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 12s/epoch - 17ms/step
# Epoch 15/15
#
# Epoch 15: saving model to model/cp-0015
# INFO:tensorflow:Assets written to: model/cp-0015/assets
# 732/732 - 12s - loss: 1.5004e-04 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0172 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 12s/epoch - 17ms/step
# Model trainined in 191 s

# %%
import matplotlib.pyplot as plt
def plotLoss(history, lossOnly=False):
    plt.figure()
    plt.title("Cross Entropy Loss")
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')

    plt.figure()
    plt.title("Accuracy")
    plt.plot(history.history['acc'], label='acc')
    plt.plot(history.history['val_acc'], label='val_acc')
    plt.xlabel('Epoch')
    plt.legend()
    
plotLoss(history)

# %%
import pretty
import seaborn as sn
import pandas as pd

classesList = ["Close", "Open"]

def confusionPlot(y, pred, numClasses, classes, cmap="PuRd"):
    confusion = tf.math.confusion_matrix(y, pred, num_classes=numClasses)
    confusionArray = confusion.numpy()
    df_cm = pd.DataFrame(confusionArray, classes, classes)
    plt.figure(figsize=(8, 6))
    sn.heatmap(df_cm, annot=True)  # font size
    plt.xlim([0, numClasses])
    plt.ylim([numClasses, 0])
    pretty.pretty_plot_confusion_matrix(df_cm, cmap=cmap)
    plt.xlim([0, numClasses+1])
    plt.ylim([numClasses+1, 0])

#myModel = tf.keras.models.load_model('myModel')
myModel = tf.keras.models.load_model('model/cp-0011')
cmap = pretty.cmaps[123]
testPredRaw = myModel.predict(testX)
testPred = list(np.argmax(testPredRaw, axis=1))
confusionPlot(testY, testPred, 2, classesList, cmap)

#confusionPlot()
# Out:
# 2022-04-02 20:57:44.790121: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
