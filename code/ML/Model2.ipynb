# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras import layers
import time
import pandas as pd


def readBackFiles(folder):
    x = []
    data=pd.read_csv(folder + "gx.csv", header=None)
    check = data.isna().sum()
    if sum(check) > 0:
        raise Exception("NANs in data")
    x.append(data.values)
    x = np.dstack(x)
    y = pd.read_csv(folder + "class.csv", header=None)
    return x, y

classes = {0:"Close", 1:"Open"}

TrainFolder = "../../data/train/"
ValFolder = "../../data/val/"
TestFolder = "../../data/test/"

trainX,trainY = readBackFiles(TrainFolder)
trainYOneHot = tf.keras.utils.to_categorical(trainY)
print("Train")
print(trainX.shape)
print(trainY.shape)
valX,valY = readBackFiles(ValFolder)
valYOneHot = tf.keras.utils.to_categorical(valY)
print("Val")
print(valX.shape)
print(valY.shape)
print("Test")
testX,testY = readBackFiles(TestFolder)
print(testX.shape)
print(testY.shape)
testYOneHot = tf.keras.utils.to_categorical(testY)
# Out:
# Train
# (30160, 600, 1)
# (30160, 1)
# Val
# (72, 600, 1)
# (72, 1)
# Test
# (90, 600, 1)
# (90, 1)

# %%
def fitModel(model, trainX, trainY, valX, valY, epochs, batchSize, verbose,myCallbacks=None):
    model.compile(loss='categorical_crossentropy', optimizer=tf.optimizers.Adam(learning_rate=.0001),
                  metrics=['acc', "Precision", "Recall"])
    if myCallbacks == None:
        history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchSize, verbose=verbose,
                            validation_data=(valX, valY))

    else:
        history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchSize, verbose=verbose,
                            validation_data=(valX, valY), callbacks=myCallbacks)
    return model, history

def createModel2(xShape, yShape):
    verbose = 1
    _, timesteps, channels = xShape
    _, numCategories = yShape
    model = tf.keras.Sequential([
        layers.Conv1D(filters=64, kernel_size=8, strides=2, activation="relu", input_shape=(timesteps, channels)),
        layers.Dropout(.2),
        layers.MaxPool1D(pool_size=2),
        layers.BatchNormalization(),
        layers.Conv1D(filters=48, kernel_size=4, strides=1, activation="relu", input_shape=(timesteps, channels)),
        layers.Dropout(.2),
        layers.MaxPool1D(pool_size=2),
        layers.BatchNormalization(),
        layers.Flatten(),
        layers.Dense(768, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(.5),
        layers.Dense(384, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(.5),
        #layers.Dense(30, activation="relu"),
        layers.Dense(numCategories, activation="softmax")
    ])
    return model

def createModel(xShape, yShape):
    verbose = 1
    _, timesteps, channels = xShape
    _, numCategories = yShape
    model = tf.keras.Sequential([
        layers.Conv1D(filters=32, kernel_size=4, strides=2, activation="relu", input_shape=(timesteps, channels)),
        layers.Dropout(.2),
        layers.MaxPool1D(pool_size=2),
        layers.BatchNormalization(),
        layers.Conv1D(filters=24, kernel_size=2, strides=1, activation="relu", input_shape=(timesteps, channels)),
        layers.Dropout(.2),
        layers.MaxPool1D(pool_size=2),
        layers.BatchNormalization(),
        layers.Flatten(),
        layers.Dense(64, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(.5),
        layers.Dense(32, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(.5),
        #layers.Dense(30, activation="relu"),
        layers.Dense(numCategories, activation="softmax")
    ])
    return model

# %%
earlyStoppingPatience = 5 # Early stopping
reduceLRPatience = 4
epochs = 15
batchSize = 32

#BaseModelPath = "model/mymodel.h5"
BaseModelPath = "model/cp-{epoch:04d}"
earlystopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=earlyStoppingPatience,restore_best_weights=False, mode="max", verbose=1)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_acc', factor=0.1,patience=reduceLRPatience, 
                              verbose=1, mode='max')
checkpoint = tf.keras.callbacks.ModelCheckpoint(BaseModelPath,  verbose=1, save_best_only=False,
    save_weights_only=False, save_freq='epoch')
myCallbacks = [checkpoint]
#myCallbacks = [reduce_lr, checkpoint]
#myCallbacks = [earlystopping, reduce_lr, checkpoint]

# %%
# !rm -rf model
# !mkdir model
start = time.time()
myModel = createModel(trainX.shape, trainYOneHot.shape)
myModel, history = fitModel(myModel, trainX, trainYOneHot, valX, valYOneHot, epochs, batchSize, 2, myCallbacks)
end = time.time() - start
print("Model trainined in %d s" % end)

#numEpochsUsed = len(history.history["loss"]) - earlyStoppingPatience
#print("Trained using %d epochs" % numEpochsUsed)
# Out:
# Metal device set to: Apple M1 Max
#
# systemMemory: 64.00 GB
# maxCacheSize: 21.33 GB
#
# Epoch 1/15
# 2022-04-03 14:19:11.826607: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-04-03 14:19:11.826771: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-04-03 14:19:12.011720: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-04-03 14:19:12.520994: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: saving model to model/cp-0001
# 2022-04-03 14:19:29.047573: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-03 14:19:29.512033: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: model/cp-0001/assets
# 943/943 - 18s - loss: 0.0980 - acc: 0.9661 - precision: 0.9661 - recall: 0.9661 - val_loss: 0.0429 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 18s/epoch - 19ms/step
# Epoch 2/15
#
# Epoch 2: saving model to model/cp-0002
# INFO:tensorflow:Assets written to: model/cp-0002/assets
# 943/943 - 16s - loss: 0.0171 - acc: 0.9965 - precision: 0.9965 - recall: 0.9965 - val_loss: 0.0204 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 16s/epoch - 17ms/step
# Epoch 3/15
#
# Epoch 3: saving model to model/cp-0003
# INFO:tensorflow:Assets written to: model/cp-0003/assets
# 943/943 - 16s - loss: 0.0074 - acc: 0.9987 - precision: 0.9987 - recall: 0.9987 - val_loss: 0.0111 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 16s/epoch - 17ms/step
# Epoch 4/15
#
# Epoch 4: saving model to model/cp-0004
# INFO:tensorflow:Assets written to: model/cp-0004/assets
# 943/943 - 16s - loss: 0.0035 - acc: 0.9996 - precision: 0.9996 - recall: 0.9996 - val_loss: 0.0063 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 16s/epoch - 17ms/step
# Epoch 5/15
#
# Epoch 5: saving model to model/cp-0005
# INFO:tensorflow:Assets written to: model/cp-0005/assets
# 943/943 - 16s - loss: 0.0023 - acc: 0.9997 - precision: 0.9997 - recall: 0.9997 - val_loss: 0.0065 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 16s/epoch - 17ms/step
# Epoch 6/15
#
# Epoch 6: saving model to model/cp-0006
# INFO:tensorflow:Assets written to: model/cp-0006/assets
# 943/943 - 16s - loss: 0.0019 - acc: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0033 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 16s/epoch - 17ms/step
# Epoch 7/15
#
# Epoch 7: saving model to model/cp-0007
# INFO:tensorflow:Assets written to: model/cp-0007/assets
# 943/943 - 16s - loss: 0.0010 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0066 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 16s/epoch - 17ms/step
# Epoch 8/15
#
# Epoch 8: saving model to model/cp-0008
# INFO:tensorflow:Assets written to: model/cp-0008/assets
# 943/943 - 16s - loss: 7.9688e-04 - acc: 0.9999 - precision: 0.9999 - recall: 0.9999 - val_loss: 0.0080 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 16s/epoch - 17ms/step
# Epoch 9/15
#
# Epoch 9: saving model to model/cp-0009
# INFO:tensorflow:Assets written to: model/cp-0009/assets
# 943/943 - 16s - loss: 5.3016e-04 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0043 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 16s/epoch - 17ms/step
# Epoch 10/15
#
# Epoch 10: saving model to model/cp-0010
# INFO:tensorflow:Assets written to: model/cp-0010/assets
# 943/943 - 16s - loss: 3.9216e-04 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0171 - val_acc: 0.9861 - val_precision: 0.9861 - val_recall: 0.9861 - 16s/epoch - 17ms/step
# Epoch 11/15
#
# Epoch 11: saving model to model/cp-0011
# INFO:tensorflow:Assets written to: model/cp-0011/assets
# 943/943 - 16s - loss: 0.0011 - acc: 0.9997 - precision: 0.9997 - recall: 0.9997 - val_loss: 0.0029 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 16s/epoch - 17ms/step
# Epoch 12/15
#
# Epoch 12: saving model to model/cp-0012
# INFO:tensorflow:Assets written to: model/cp-0012/assets
# 943/943 - 16s - loss: 0.0010 - acc: 0.9997 - precision: 0.9997 - recall: 0.9997 - val_loss: 0.0114 - val_acc: 0.9861 - val_precision: 0.9861 - val_recall: 0.9861 - 16s/epoch - 17ms/step
# Epoch 13/15
#
# Epoch 13: saving model to model/cp-0013
# INFO:tensorflow:Assets written to: model/cp-0013/assets
# 943/943 - 16s - loss: 6.4435e-04 - acc: 0.9999 - precision: 0.9999 - recall: 0.9999 - val_loss: 0.0209 - val_acc: 0.9861 - val_precision: 0.9861 - val_recall: 0.9861 - 16s/epoch - 17ms/step
# Epoch 14/15
#
# Epoch 14: saving model to model/cp-0014
# INFO:tensorflow:Assets written to: model/cp-0014/assets
# 943/943 - 16s - loss: 2.5086e-04 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0205 - val_acc: 0.9861 - val_precision: 0.9861 - val_recall: 0.9861 - 16s/epoch - 17ms/step
# Epoch 15/15
#
# Epoch 15: saving model to model/cp-0015
# INFO:tensorflow:Assets written to: model/cp-0015/assets
# 943/943 - 16s - loss: 8.0476e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0041 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 16s/epoch - 17ms/step
# Model trainined in 242 s

# %%
import matplotlib.pyplot as plt
def plotLoss(history, lossOnly=False):
    plt.figure()
    plt.title("Cross Entropy Loss")
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')

    plt.figure()
    plt.title("Accuracy")
    plt.plot(history.history['acc'], label='acc')
    plt.plot(history.history['val_acc'], label='val_acc')
    plt.xlabel('Epoch')
    plt.legend()
    
plotLoss(history)

# %%
import pretty
import seaborn as sn
import pandas as pd

classesList = ["Close", "Open"]

def confusionPlot(y, pred, numClasses, classes, cmap="PuRd"):
    confusion = tf.math.confusion_matrix(y, pred, num_classes=numClasses)
    confusionArray = confusion.numpy()
    df_cm = pd.DataFrame(confusionArray, classes, classes)
    plt.figure(figsize=(8, 6))
    sn.heatmap(df_cm, annot=True)  # font size
    plt.xlim([0, numClasses])
    plt.ylim([numClasses, 0])
    pretty.pretty_plot_confusion_matrix(df_cm, cmap=cmap)
    plt.xlim([0, numClasses+1])
    plt.ylim([numClasses+1, 0])

#myModel = tf.keras.models.load_model('myModel')
myModel = tf.keras.models.load_model('model/cp-0009')
cmap = pretty.cmaps[123]
testPredRaw = myModel.predict(testX)
testPred = list(np.argmax(testPredRaw, axis=1))
confusionPlot(testY, testPred, 2, classesList, cmap)

#confusionPlot()
# Out:
# 2022-04-03 14:34:23.471140: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
